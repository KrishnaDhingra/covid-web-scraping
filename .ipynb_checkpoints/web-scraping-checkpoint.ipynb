# %%
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import requests

# %%
def getPageHTML(url):
    result = requests.get(url)
    doc = BeautifulSoup(result.text, 'html.parser')
    return doc

# %%
def getGlobalInfo(doc):
    
    tableBody = doc.find('table', {"id": "main_table_countries_today"}).tbody
    rows = tableBody.find_all("tr", style="")[1:]

    globalInfo = []
    for row in rows:
        countryInfo = {}
        tableData = row.find_all('td')

        countryInfo["country"] = tableData[1].a.string
        countryInfo["total cases"] = tableData[2].string
        countryInfo["total deaths"] = tableData[4].string
        countryInfo["total recovered"] = tableData[6].string
        countryInfo["active cases"] = tableData[8].string
        countryInfo["serious critical"] = tableData[9].string
        countryInfo["total tests"] = tableData[12].string
        
        if tableData[14].a !=None:
            countryInfo["population"] = tableData[14].a.string
        else:
            countryInfo["population"] = tableData[14].string
        globalInfo.append(countryInfo)
        
    return globalInfo

# %%
def getCountry(userCountry):
    for countryInfo in globalInfo: 
        if countryInfo['country'].lower() == userCountry.lower():
            return True, countryInfo
    return False, "Can't find the country"

# %%
def plotGraph(countryInfo):
    x = list(countryInfo.keys())
    h = list(countryInfo.values())
    plt.bar(x, h)
    plt.title(f'Covid information of India')
    plt.show()

# %%
def askForSpecificCountry():
    while True:
        userCountry = input("Please type the country of whose information you want to get or type 'skip' to move forward")
        if userCountry.lower() != 'skip':
            exists, message = getCountry(userCountry)
#           if the getCountry function returns true than the country exists the the country
            if(exists):
#               print an empty line so it looks good
                print()
#               using this loop the country is printed in a pretty manner
                for i in message:
                    print(f'{i} : {message[i]}')
                print()
                plotGraph(message)
            else:
#               if the country doesn't exists the just print the message
                print()
                print(message)
        else: 
            break

# %%
doc = getPageHTML('https://www.worldometers.info/coronavirus/')
globalInfo = getGlobalInfo(doc)
    
for country in globalInfo:
    for countryInfo in country:
        print(f'{countryInfo} : {country[countryInfo]}')
    print()
    
askForSpecificCountry()
# Out:
# country : USA
# total cases : 81,292,281
# total deaths : 994,811
# total recovered : 56,631,719
# active cases : 23,665,751
# serious critical : 3,584
# total tests : 968,738,662
# population : 334,305,317
#
# country : India
# total cases : 43,001,477
# total deaths : 516,162
# total recovered : 42,454,546
# active cases : 30,769
# serious critical : 8,944
# total tests : 781,224,304
# population : 1,403,087,655
#
# country : Brazil
# total cases : 29,478,039
# total deaths : 656,003
# total recovered : 28,063,760
# active cases : 758,276
# serious critical : 8,318
# total tests : 63,776,166
# population : 215,130,305
#
# country : France
# total cases : 23,758,447
# total deaths : 140,613
# total recovered : 22,394,358
# active cases : 1,223,476
# serious critical : 1,783
# total tests : 246,629,975
# population : 65,519,286
#
# country : UK
# total cases : 20,001,627
# total deaths : 163,386
# total recovered : 18,507,001
# active cases : 1,331,240
# serious critical : 281
# total tests : 494,375,963
# population : 68,492,797
#
# country : Germany
# total cases : 18,122,779
# total deaths : 127,061
# total recovered : 14,142,500
# active cases : 3,853,218
# serious critical : 2,494
# total tests : 104,701,826
# population : 84,239,806
#
# country : Russia
# total cases : 17,484,257
# total deaths : 363,039
# total recovered : 15,934,645
# active cases : 1,186,573
# serious critical : 2,300
# total tests : 273,400,000
# population : 146,040,943
#
# country : Turkey
# total cases : 14,644,382
# total deaths : 96,954
# total recovered : 14,271,428
# active cases : 276,000
# serious critical : 975
# total tests : 149,811,965
# population : 85,883,036
#
# country : Italy
# total cases : 13,645,834
# total deaths : 157,442
# total recovered : 12,400,175
# active cases : 1,088,217
# serious critical : 473
# total tests : 194,373,101
# population : 60,310,541
#
# country : Spain
# total cases : 11,260,040
# total deaths : 101,416
# total recovered : 10,502,784
# active cases : 655,840
# serious critical : 682
# total tests : 471,036,328
# population : 46,785,594
#
# country : Argentina
# total cases : 8,985,836
# total deaths : 127,334
# total recovered : 8,791,259
# active cases : 67,243
# serious critical : 741
# total tests : 34,925,083
# population : 45,901,385
#
# country : S. Korea
# total cases : 8,250,592
# total deaths : 11,481
# total recovered : N/A
# active cases : N/A
# serious critical : 1,159
# total tests : 15,804,065
# population : 51,344,266
#
# country : Netherlands
# total cases : 7,380,902
# total deaths : 21,755
# total recovered : 5,821,253
# active cases : 1,537,894
# serious critical : 155
# total tests : 21,107,399
# population : 17,199,386
#
# country : Iran
# total cases : 7,135,719
# total deaths : 139,387
# total recovered : 6,805,081
# active cases : 191,251
# serious critical : 2,234
# total tests : 48,534,882
# population : 85,821,796
#
# country : Vietnam
# total cases : 6,820,458
# total deaths : 41,607
# total recovered : 3,547,488
# active cases : 3,231,363
# serious critical : 4,210
# total tests : 81,949,741
# population : 98,828,683
#
# country : Colombia
# total cases : 6,078,487
# total deaths : 139,361
# total recovered : 5,910,525
# active cases : 28,601
# serious critical : 342
# total tests : 33,595,864
# population : 51,805,575
#
# country : Indonesia
# total cases : 5,939,082
# total deaths : 153,212
# total recovered : 5,523,393
# active cases : 262,477
# serious critical : 2,771
# total tests : 89,980,099
# population : 278,444,349
#
# country : Japan
# total cases : 5,911,813
# total deaths : 26,600
# total recovered : 5,344,759
# active cases : 540,454
# serious critical : 1,090
# total tests : 41,509,477
# population : 125,817,627
#
# country : Poland
# total cases : 5,863,414
# total deaths : 113,980
# total recovered : 5,215,898
# active cases : 533,536
# serious critical : 457
# total tests : 34,844,547
# population : 37,776,076
#
# country : Mexico
# total cases : 5,619,780
# total deaths : 321,619
# total recovered : 4,912,654
# active cases : 385,507
# serious critical : 4,798
# total tests : 15,396,315
# population : 131,237,376
#
# country : Ukraine
# total cases : 4,917,757
# total deaths : 107,340
# total recovered : N/A
# active cases : N/A
# serious critical : 177
# total tests : 19,521,252
# population : 43,286,684
#
# country : Malaysia
# total cases : 3,900,433
# total deaths : 34,099
# total recovered : 3,567,003
# active cases : 299,331
# serious critical : 374
# total tests : 52,837,322
# population : 33,071,438
#
# country : Australia
# total cases : 3,767,956
# total deaths : 5,665
# total recovered : 3,411,134
# active cases : 351,157
# serious critical : 96
# total tests : 65,006,859
# population : 26,003,221
#
# country : Israel
# total cases : 3,737,352
# total deaths : 10,405
# total recovered : 3,686,283
# active cases : 40,664
# serious critical : 308
# total tests : 41,373,364
# population : 9,326,000
#
# country : Czechia
# total cases : 3,716,181
# total deaths : 39,271
# total recovered : 3,596,100
# active cases : 80,810
# serious critical : 129
# total tests : 53,196,535
# population : 10,742,788
#
# country : South Africa
# total cases : 3,698,803
# total deaths : 99,767
# total recovered : 3,584,293
# active cases : 14,743
# serious critical : 546
# total tests : 23,485,052
# population : 60,580,760
#
# country : Belgium
# total cases : 3,683,784
# total deaths : 30,492
# total recovered : 3,417,067
# active cases : 236,225
# serious critical : 181
# total tests : 32,285,642
# population : 11,675,449
#
# country : Philippines
# total cases : 3,672,661
# total deaths : 57,880
# total recovered : 3,569,387
# active cases : 45,394
# serious critical : 289
# total tests : 28,624,002
# population : 112,062,132
#
# country : Peru
# total cases : 3,537,488
# total deaths : 211,619
# total recovered : N/A
# active cases : N/A
# serious critical : 658
# total tests : 28,001,696
# population : 33,753,151
#
# country : Canada
# total cases : 3,383,572
# total deaths : 37,061
# total recovered : 3,230,590
# active cases : 115,921
# serious critical : 510
# total tests : 58,845,250
# population : 38,305,178
#
# country : Portugal
# total cases : 3,380,263
# total deaths : 21,285
# total recovered : 2,876,177
# active cases : 482,801
# serious critical : 70
# total tests : 37,805,639
# population : 10,146,118
#
# country : Chile
# total cases : 3,353,259
# total deaths : 44,246
# total recovered : 2,634,821
# active cases : 674,192
# serious critical : 875
# total tests : 34,410,260
# population : 19,395,390
#
# country : Austria
# total cases : 3,335,900
# total deaths : 15,320
# total recovered : 2,887,173
# active cases : 433,407
# serious critical : 211
# total tests : 169,094,014
# population : 9,093,838
#
# country : Thailand
# total cases : 3,276,098
# total deaths : 23,998
# total recovered : 3,026,969
# active cases : 225,131
# serious critical : 687
# total tests : 17,270,775
# population : 70,098,011
#
# country : Switzerland
# total cases : 3,192,119
# total deaths : 13,441
# total recovered : 2,566,023
# active cases : 612,655
# serious critical : 144
# total tests : 19,553,805
# population : 8,762,312
#
# country : Denmark
# total cases : 2,843,361
# total deaths : 5,300
# total recovered : 2,677,962
# active cases : 160,099
# serious critical : 29
# total tests : 126,439,626
# population : 5,826,910
#
# country : Romania
# total cases : 2,806,881
# total deaths : 64,581
# total recovered : 2,606,660
# active cases : 135,640
# serious critical : 502
# total tests : 21,679,709
# population : 19,019,326
#
# country : Greece
# total cases : 2,732,866
# total deaths : 26,792
# total recovered : 2,472,529
# active cases : 233,545
# serious critical : 348
# total tests : 70,323,524
# population : 10,336,422
#
# country : Sweden
# total cases : 2,473,707
# total deaths : 17,961
# total recovered : 2,396,572
# active cases : 59,174
# serious critical : 42
# total tests : 18,342,988
# population : 10,206,416
#
# country : Iraq
# total cases : 2,315,134
# total deaths : 25,119
# total recovered : 2,270,809
# active cases : 19,206
# serious critical : 72
# total tests : 18,204,435
# population : 41,757,127
#
# country : Bangladesh
# total cases : 1,950,357
# total deaths : 29,112
# total recovered : 1,867,161
# active cases : 54,084
# serious critical : 1,264
# total tests : 13,692,423
# population : 167,480,871
#
# country : Serbia
# total cases : 1,949,953
# total deaths : 15,647
# total recovered : 1,892,639
# active cases : 41,667
# serious critical : 47
# total tests : 8,989,852
# population : 8,677,484
#
# country : Hungary
# total cases : 1,820,767
# total deaths : 44,895
# total recovered : 1,667,111
# active cases : 108,761
# serious critical : 90
# total tests : 10,965,815
# population : 9,618,611
#
# country : Jordan
# total cases : 1,680,179
# total deaths : 13,959
# total recovered : 1,647,266
# active cases : 18,954
# serious critical : 694
# total tests : 16,499,905
# population : 10,375,464
#
# country : Georgia
# total cases : 1,639,678
# total deaths : 16,612
# total recovered : 1,594,011
# active cases : 29,055
# serious critical : None
# total tests : 16,142,347
# population : 3,976,137
#
# country : Slovakia
# total cases : 1,608,668
# total deaths : 19,040
# total recovered : 1,463,345
# active cases : 126,283
# serious critical : 214
# total tests : 6,673,583
# population : 5,464,142
#
# country : Pakistan
# total cases : 1,520,634
# total deaths : 30,319
# total recovered : 1,472,828
# active cases : 17,487
# serious critical : 546
# total tests : 27,036,710
# population : 228,186,231
#
# country : Norway
# total cases : 1,368,165
# total deaths : 1,826
# total recovered : N/A
# active cases : N/A
# serious critical : 24
# total tests : 9,852,076
# population : 5,493,367
#
# country : Ireland
# total cases : 1,365,467
# total deaths : 6,638
# total recovered : 1,248,933
# active cases : 109,896
# serious critical : 44
# total tests : 11,577,799
# population : 5,031,622
#
# country : Kazakhstan
# total cases : 1,304,723
# total deaths : 13,650
# total recovered : 1,282,851
# active cases : 8,222
# serious critical : 528
# total tests : 11,575,012
# population : 19,158,790
#
# country : Morocco
# total cases : 1,162,322
# total deaths : 16,050
# total recovered : 1,145,647
# active cases : 625
# serious critical : 293
# total tests : 11,237,010
# population : 37,654,831
#
# country : Bulgaria
# total cases : 1,119,474
# total deaths : 36,222
# total recovered : 889,474
# active cases : 193,778
# serious critical : 278
# total tests : 9,422,447
# population : 6,859,444
#
# country : Lebanon
# total cases : 1,086,382
# total deaths : 10,226
# total recovered : 1,009,978
# active cases : 66,178
# serious critical : 186
# total tests : 4,795,578
# population : 6,773,435
#
# country : Croatia
# total cases : 1,079,397
# total deaths : 15,392
# total recovered : 1,052,932
# active cases : 11,073
# serious critical : 42
# total tests : 4,606,262
# population : 4,062,189
#
# country : Cuba
# total cases : 1,079,111
# total deaths : 8,503
# total recovered : 1,067,982
# active cases : 2,626
# serious critical : 23
# total tests : 12,920,253
# population : 11,314,852
#
# country : Tunisia
# total cases : 1,029,762
# total deaths : 28,065
# total recovered : 983,630
# active cases : 18,067
# serious critical : 74
# total tests : 4,475,031
# population : 12,029,014
#
# country : Lithuania
# total cases : 980,331
# total deaths : 8,692
# total recovered : 898,089
# active cases : 73,550
# serious critical : 61
# total tests : 7,935,486
# population : 2,657,665
#
# country : Nepal
# total cases : 978,107
# total deaths : 11,950
# total recovered : 961,781
# active cases : 4,376
# serious critical : 100
# total tests : 5,498,412
# population : 30,028,061
#
# country : Singapore
# total cases : 975,607
# total deaths : 1,170
# total recovered : 932,107
# active cases : 42,330
# serious critical : 36
# total tests : 23,396,045
# population : 5,928,627
#
# country : Hong Kong
# total cases : 975,212
# total deaths : 4,847
# total recovered : N/A
# active cases : N/A
# serious critical : 119
# total tests : 36,260,319
# population : 7,600,468
#
# country : Belarus
# total cases : 946,674
# total deaths : 6,698
# total recovered : 928,536
# active cases : 11,440
# serious critical : None
# total tests : 12,688,661
# population : 9,444,034
#
# country : Slovenia
# total cases : 929,013
# total deaths : 6,428
# total recovered : 892,689
# active cases : 29,896
# serious critical : 58
# total tests : 2,595,137
# population : 2,079,424
#
# country : Bolivia
# total cases : 898,464
# total deaths : 21,476
# total recovered : 811,581
# active cases : 65,407
# serious critical : 220
# total tests : 2,682,016
# population : 11,943,882
#
# country : UAE
# total cases : 886,687
# total deaths : 2,302
# total recovered : 854,007
# active cases : 30,378
# serious critical : None
# total tests : 143,872,681
# population : 10,093,691
#
# country : Uruguay
# total cases : 868,952
# total deaths : 7,116
# total recovered : 852,383
# active cases : 9,453
# serious critical : 63
# total tests : 5,845,597
# population : 3,494,215
#
# country : Ecuador
# total cases : 849,699
# total deaths : 35,348
# total recovered : N/A
# active cases : N/A
# serious critical : 759
# total tests : 2,470,170
# population : 18,098,750
#
# country : Costa Rica
# total cases : 827,346
# total deaths : 8,202
# total recovered : 743,751
# active cases : 75,393
# serious critical : 90
# total tests : 3,854,668
# population : 5,173,262
#
# country : Guatemala
# total cases : 809,586
# total deaths : 17,178
# total recovered : 771,331
# active cases : 21,077
# serious critical : 5
# total tests : 4,099,105
# population : 18,479,171
#
# country : Azerbaijan
# total cases : 791,077
# total deaths : 9,633
# total recovered : 779,987
# active cases : 1,457
# serious critical : None
# total tests : 6,646,110
# population : 10,294,666
#
# country : Finland
# total cases : 782,912
# total deaths : 2,783
# total recovered : 46,000
# active cases : 734,129
# serious critical : 38
# total tests : 10,205,163
# population : 5,555,366
#
# country : Latvia
# total cases : 761,074
# total deaths : 5,484
# total recovered : 667,949
# active cases : 87,641
# serious critical : 36
# total tests : 6,950,241
# population : 1,850,717
#
# country : Panama
# total cases : 760,405
# total deaths : 8,146
# total recovered : 749,824
# active cases : 2,435
# serious critical : 16
# total tests : 5,609,933
# population : 4,430,296
#
# country : Saudi Arabia
# total cases : 749,268
# total deaths : 9,024
# total recovered : 731,638
# active cases : 8,606
# serious critical : 223
# total tests : 41,320,890
# population : 35,736,063
#
# country : Sri Lanka
# total cases : 657,435
# total deaths : 16,419
# total recovered : 624,440
# active cases : 16,576
# serious critical : None
# total tests : 6,368,159
# population : 21,566,023
#
# country : Paraguay
# total cases : 646,495
# total deaths : 18,555
# total recovered : 621,615
# active cases : 6,325
# serious critical : 75
# total tests : 2,563,855
# population : 7,281,584
#
# country : Kuwait
# total cases : 626,609
# total deaths : 2,552
# total recovered : 620,648
# active cases : 3,409
# serious critical : 9
# total tests : 7,763,313
# population : 4,378,000
#
# country : Myanmar
# total cases : 607,844
# total deaths : 19,418
# total recovered : 561,667
# active cases : 26,759
# serious critical : None
# total tests : 7,455,368
# population : 55,030,431
#
# country : Palestine
# total cases : 580,165
# total deaths : 5,326
# total recovered : 571,646
# active cases : 3,193
# serious critical : 46
# total tests : 3,078,533
# population : 5,303,036
#
# country : Dominican Republic
# total cases : 576,904
# total deaths : 4,375
# total recovered : 572,092
# active cases : 437
# serious critical : 20
# total tests : 3,179,742
# population : 11,032,987
#
# country : Bahrain
# total cases : 541,184
# total deaths : 1,464
# total recovered : 528,300
# active cases : 11,420
# serious critical : 6
# total tests : 9,523,578
# population : 1,802,070
#
# country : Estonia
# total cases : 538,673
# total deaths : 2,376
# total recovered : 442,625
# active cases : 93,672
# serious critical : 16
# total tests : 3,193,333
# population : 1,328,053
#
# country : Venezuela
# total cases : 519,059
# total deaths : 5,663
# total recovered : 510,178
# active cases : 3,218
# serious critical : 230
# total tests : 3,359,014
# population : 28,298,841
#
# country : Moldova
# total cases : 508,917
# total deaths : 11,368
# total recovered : 492,462
# active cases : 5,087
# serious critical : 78
# total tests : 3,100,469
# population : 4,018,009
#
# country : Libya
# total cases : 500,760
# total deaths : 6,365
# total recovered : 486,171
# active cases : 8,224
# serious critical : 119
# total tests : 2,460,605
# population : 7,030,236
#
# country : Egypt
# total cases : 495,373
# total deaths : 24,277
# total recovered : 424,831
# active cases : 46,265
# serious critical : 122
# total tests : 3,693,367
# population : 105,616,776
#
# country : Ethiopia
# total cases : 469,329
# total deaths : 7,488
# total recovered : 421,540
# active cases : 40,301
# serious critical : 47
# total tests : 4,581,546
# population : 119,804,676
#
# country : Mongolia
# total cases : 467,359
# total deaths : 2,177
# total recovered : 313,256
# active cases : 151,926
# serious critical : 192
# total tests : 4,030,048
# population : 3,368,083
#
# country : New Zealand
# total cases : 438,477
# total deaths : 135
# total recovered : 238,495
# active cases : 199,847
# serious critical : None
# total tests : 6,878,730
# population : 5,002,100
#
# country : Armenia
# total cases : 422,202
# total deaths : 8,589
# total recovered : 409,047
# active cases : 4,566
# serious critical : None
# total tests : 2,944,317
# population : 2,972,667
#
# country : Honduras
# total cases : 417,201
# total deaths : 10,842
# total recovered : 131,100
# active cases : 275,259
# serious critical : 105
# total tests : 1,263,329
# population : 10,172,546
#
# country : Oman
# total cases : 387,180
# total deaths : 4,250
# total recovered : 380,425
# active cases : 2,505
# serious critical : 23
# total tests : 25,000,000
# population : 5,327,407
#
# country : Bosnia and Herzegovina
# total cases : 373,799
# total deaths : 15,661
# total recovered : 192,218
# active cases : 165,920
# serious critical : None
# total tests : 1,725,264
# population : 3,246,095
#
# country : Cyprus
# total cases : 363,792
# total deaths : 904
# total recovered : 124,370
# active cases : 238,518
# serious critical : 60
# total tests : 9,477,138
# population : 1,222,313
#
# country : Qatar
# total cases : 359,517
# total deaths : 677
# total recovered : 357,858
# active cases : 982
# serious critical : 3
# total tests : 3,397,422
# population : 2,807,805
#
# country : Kenya
# total cases : 323,237
# total deaths : 5,647
# total recovered : 317,527
# active cases : 63
# serious critical : 1
# total tests : 3,457,194
# population : 55,785,178
#
# country : Réunion
# total cases : 318,695
# total deaths : 689
# total recovered : 306,072
# active cases : 11,934
# serious critical : 41
# total tests : 1,535,875
# population : 906,183
#
# country : Zambia
# total cases : 315,623
# total deaths : 3,962
# total recovered : 310,706
# active cases : 955
# serious critical : 1
# total tests : 3,322,571
# population : 19,259,064
#
# country : North Macedonia
# total cases : 302,224
# total deaths : 9,159
# total recovered : 291,144
# active cases : 1,921
# serious critical : None
# total tests : 1,904,444
# population : 2,083,228
#
# country : Albania
# total cases : 272,885
# total deaths : 3,487
# total recovered : 268,764
# active cases : 634
# serious critical : 13
# total tests : 1,762,808
# population : 2,872,450
#
# country : Algeria
# total cases : 265,496
# total deaths : 6,869
# total recovered : 178,117
# active cases : 80,510
# serious critical : 7
# total tests : 230,861
# population : 45,197,705
#
# country : Botswana
# total cases : 263,950
# total deaths : 2,619
# total recovered : 259,434
# active cases : 1,897
# serious critical : 1
# total tests : 2,026,898
# population : 2,432,369
#
# country : Nigeria
# total cases : 255,092
# total deaths : 3,142
# total recovered : 249,457
# active cases : 2,493
# serious critical : 11
# total tests : 4,589,725
# population : 214,825,321
#
# country : Zimbabwe
# total cases : 243,650
# total deaths : 5,418
# total recovered : 233,264
# active cases : 4,968
# serious critical : 12
# total tests : 2,144,172
# population : 15,230,956
#
# country : Uzbekistan
# total cases : 237,384
# total deaths : 1,637
# total recovered : 234,860
# active cases : 887
# serious critical : 23
# total tests : 1,377,915
# population : 34,294,291
#
# country : Montenegro
# total cases : 231,927
# total deaths : 2,696
# total recovered : 228,450
# active cases : 781
# serious critical : 60
# total tests : 1,193,819
# population : 628,201
#
# country : Mozambique
# total cases : 225,200
# total deaths : 2,199
# total recovered : 221,989
# active cases : 1,012
# serious critical : 13
# total tests : 1,287,004
# population : 32,743,820
#
# country : Kyrgyzstan
# total cases : 200,776
# total deaths : 2,976
# total recovered : 195,985
# active cases : 1,815
# serious critical : 131
# total tests : 1,907,195
# population : 6,707,270
#
# country : Luxembourg
# total cases : 197,701
# total deaths : 1,010
# total recovered : 183,716
# active cases : 12,975
# serious critical : 4
# total tests : 4,114,873
# population : 643,299
#
# country : Afghanistan
# total cases : 176,918
# total deaths : 7,651
# total recovered : 159,569
# active cases : 9,698
# serious critical : 1,124
# total tests : 909,246
# population : 40,418,964
#
# country : Maldives
# total cases : 174,658
# total deaths : 297
# total recovered : 163,687
# active cases : 10,674
# serious critical : 25
# total tests : 2,213,831
# population : 556,735
#
# country : Iceland
# total cases : 169,258
# total deaths : 91
# total recovered : 75,685
# active cases : 93,482
# serious critical : 6
# total tests : 1,844,753
# population : 345,011
#
# country : Uganda
# total cases : 163,560
# total deaths : 3,595
# total recovered : 100,129
# active cases : 59,836
# serious critical : 9
# total tests : 2,513,469
# population : 48,195,835
#
# country : Ghana
# total cases : 160,761
# total deaths : 1,445
# total recovered : 159,227
# active cases : 89
# serious critical : 1
# total tests : 2,376,530
# population : 32,175,848
#
# country : Namibia
# total cases : 157,471
# total deaths : 4,014
# total recovered : 153,069
# active cases : 388
# serious critical : 1
# total tests : 970,775
# population : 2,619,162
#
# country : El Salvador
# total cases : 156,364
# total deaths : 4,104
# total recovered : 132,410
# active cases : 19,850
# serious critical : 153
# total tests : 1,758,939
# population : 6,541,893
#
# country : Laos
# total cases : 149,131
# total deaths : 643
# total recovered : 7,660
# active cases : 140,828
# serious critical : None
# total tests : 1,002,806
# population : 7,455,144
#
# country : Martinique
# total cases : 135,881
# total deaths : 905
# total recovered : 104
# active cases : 134,872
# serious critical : 8
# total tests : 777,358
# population : 374,770
#
# country : Cambodia
# total cases : 134,624
# total deaths : 3,049
# total recovered : 130,407
# active cases : 1,168
# serious critical : None
# total tests : 2,907,588
# population : 17,112,559
#
# country : Trinidad and Tobago
# total cases : 133,788
# total deaths : 3,695
# total recovered : 116,951
# active cases : 13,142
# serious critical : 18
# total tests : 651,489
# population : 1,407,199
#
# country : Guadeloupe
# total cases : 130,705
# total deaths : 843
# total recovered : 2,250
# active cases : 127,612
# serious critical : 19
# total tests : 938,039
# population : 400,240
#
# country : Rwanda
# total cases : 129,615
# total deaths : 1,458
# total recovered : 45,522
# active cases : 82,635
# serious critical : None
# total tests : 4,990,831
# population : 13,498,042
#
# country : Jamaica
# total cases : 128,456
# total deaths : 2,857
# total recovered : 79,730
# active cases : 45,869
# serious critical : 25
# total tests : 889,955
# population : 2,983,160
#
# country : Brunei
# total cases : 120,600
# total deaths : 177
# total recovered : 100,048
# active cases : 20,375
# serious critical : 27
# total tests : 717,784
# population : 444,606
#
# country : Cameroon
# total cases : 119,414
# total deaths : 1,926
# total recovered : 117,263
# active cases : 225
# serious critical : 13
# total tests : 1,751,774
# population : 27,669,208
#
# country : Angola
# total cases : 98,985
# total deaths : 1,900
# total recovered : 96,939
# active cases : 146
# serious critical : None
# total tests : 1,472,075
# population : 34,603,696
#
# country : DRC
# total cases : 86,426
# total deaths : 1,335
# total recovered : 50,930
# active cases : 34,161
# serious critical : None
# total tests : 846,704
# population : 94,188,831
#
# country : Senegal
# total cases : 85,818
# total deaths : 1,964
# total recovered : 83,810
# active cases : 44
# serious critical : 3
# total tests : 1,029,625
# population : 17,493,976
#
# country : Malawi
# total cases : 85,526
# total deaths : 2,624
# total recovered : 77,189
# active cases : 5,713
# serious critical : 67
# total tests : 555,189
# population : 19,970,262
#
# country : Ivory Coast
# total cases : 81,626
# total deaths : 796
# total recovered : 80,758
# active cases : 72
# serious critical : None
# total tests : 1,450,273
# population : 27,488,732
#
# country : Suriname
# total cases : 78,860
# total deaths : 1,322
# total recovered : 49,368
# active cases : 28,170
# serious critical : None
# total tests : 233,149
# population : 595,575
#
# country : French Guiana
# total cases : 78,272
# total deaths : 394
# total recovered : 11,254
# active cases : 66,624
# serious critical : 2
# total tests : 605,055
# population : 311,842
#
# country : Malta
# total cases : 73,728
# total deaths : 619
# total recovered : 70,836
# active cases : 2,273
# serious critical : 1
# total tests : 1,211,456
# population : 443,544
#
# country : French Polynesia
# total cases : 70,826
# total deaths : 645
# total recovered : N/A
# active cases : N/A
# serious critical : 7
# total tests : None
# population : 283,671
#
# country : Eswatini
# total cases : 69,507
# total deaths : 1,392
# total recovered : 68,051
# active cases : 64
# serious critical : 11
# total tests : 488,035
# population : 1,180,601
#
# country : Fiji
# total cases : 64,154
# total deaths : 834
# total recovered : 62,248
# active cases : 1,072
# serious critical : None
# total tests : 502,686
# population : 907,498
#
# country : Madagascar
# total cases : 63,870
# total deaths : 1,377
# total recovered : 59,156
# active cases : 3,337
# serious critical : 23
# total tests : 404,843
# population : 28,901,160
#
# country : Guyana
# total cases : 63,169
# total deaths : 1,226
# total recovered : 61,772
# active cases : 171
# serious critical : 5
# total tests : 556,729
# population : 793,010
#
# country : Sudan
# total cases : 61,715
# total deaths : 4,874
# total recovered : N/A
# active cases : N/A
# serious critical : None
# total tests : 562,941
# population : 45,589,900
#
# country : Channel Islands
# total cases : 60,210
# total deaths : 147
# total recovered : 55,010
# active cases : 5,053
# serious critical : None
# total tests : 1,227,875
# population : 176,589
#
# country : New Caledonia
# total cases : 59,785
# total deaths : 306
# total recovered : 57,627
# active cases : 1,852
# serious critical : 25
# total tests : 98,964
# population : 290,168
#
# country : Mauritania
# total cases : 58,660
# total deaths : 981
# total recovered : 57,663
# active cases : 16
# serious critical : 30
# total tests : 764,268
# population : 4,857,412
#
# country : Barbados
# total cases : 57,348
# total deaths : 326
# total recovered : 55,892
# active cases : 1,130
# serious critical : None
# total tests : 600,328
# population : 287,974
#
# country : Belize
# total cases : 57,113
# total deaths : 652
# total recovered : 56,074
# active cases : 387
# serious critical : 6
# total tests : 513,045
# population : 409,904
#
# country : Cabo Verde
# total cases : 55,914
# total deaths : 401
# total recovered : 55,453
# active cases : 60
# serious critical : 23
# total tests : 400,982
# population : 566,261
#
# country : Syria
# total cases : 55,460
# total deaths : 3,120
# total recovered : 50,352
# active cases : 1,988
# serious critical : None
# total tests : 146,269
# population : 18,223,412
#
# country : Gabon
# total cases : 47,570
# total deaths : 303
# total recovered : 47,244
# active cases : 23
# serious critical : None
# total tests : 1,584,243
# population : 2,315,022
#
# country : Papua New Guinea
# total cases : 41,533
# total deaths : 639
# total recovered : 39,905
# active cases : 989
# serious critical : 7
# total tests : 249,149
# population : 9,235,242
#
# country : Seychelles
# total cases : 39,761
# total deaths : 163
# total recovered : 39,367
# active cases : 231
# serious critical : None
# total tests : None
# population : 99,383
#
# country : Curaçao
# total cases : 39,459
# total deaths : 265
# total recovered : 38,760
# active cases : 434
# serious critical : 3
# total tests : 494,095
# population : 165,235
#
# country : Andorra
# total cases : 38,794
# total deaths : 152
# total recovered : 37,925
# active cases : 717
# serious critical : 14
# total tests : 249,838
# population : 77,475
#
# country : Burundi
# total cases : 38,296
# total deaths : 38
# total recovered : 773
# active cases : 37,485
# serious critical : None
# total tests : 345,742
# population : 12,492,663
#
# country : Togo
# total cases : 36,870
# total deaths : 272
# total recovered : 36,542
# active cases : 56
# serious critical : None
# total tests : 705,993
# population : 8,608,604
#
# country : Mayotte
# total cases : 36,745
# total deaths : 187
# total recovered : 2,964
# active cases : 33,594
# serious critical : None
# total tests : 176,919
# population : 284,006
#
# country : Guinea
# total cases : 36,435
# total deaths : 440
# total recovered : 35,950
# active cases : 45
# serious critical : 8
# total tests : 660,107
# population : 13,738,299
#
# country : Mauritius
# total cases : 34,890
# total deaths : 934
# total recovered : 32,931
# active cases : 1,025
# serious critical : None
# total tests : 358,675
# population : 1,275,359
#
# country : Faeroe Islands
# total cases : 34,237
# total deaths : 28
# total recovered : 7,693
# active cases : 26,516
# serious critical : 5
# total tests : 778,000
# population : 49,179
#
# country : Aruba
# total cases : 33,796
# total deaths : 212
# total recovered : 33,522
# active cases : 62
# serious critical : 4
# total tests : 177,885
# population : 107,537
#
# country : Tanzania
# total cases : 33,773
# total deaths : 800
# total recovered : N/A
# active cases : N/A
# serious critical : 7
# total tests : None
# population : 62,626,086
#
# country : Bahamas
# total cases : 33,206
# total deaths : 773
# total recovered : 32,135
# active cases : 298
# serious critical : 11
# total tests : 224,033
# population : 399,637
#
# country : Lesotho
# total cases : 32,775
# total deaths : 697
# total recovered : 23,900
# active cases : 8,178
# serious critical : None
# total tests : 415,510
# population : 2,171,144
#
# country : Haiti
# total cases : 30,478
# total deaths : 827
# total recovered : 27,039
# active cases : 2,612
# serious critical : None
# total tests : 132,422
# population : 11,638,998
#
# country : Mali
# total cases : 30,433
# total deaths : 727
# total recovered : 29,590
# active cases : 116
# serious critical : None
# total tests : 636,320
# population : 21,242,203
#
# country : Benin
# total cases : 26,952
# total deaths : 163
# total recovered : 25,506
# active cases : 1,283
# serious critical : 5
# total tests : 604,310
# population : 12,662,979
#
# country : Somalia
# total cases : 26,400
# total deaths : 1,348
# total recovered : 13,182
# active cases : 11,870
# serious critical : None
# total tests : 400,466
# population : 16,646,891
#
# country : Isle of Man
# total cases : 25,542
# total deaths : 81
# total recovered : 23,774
# active cases : 1,687
# serious critical : None
# total tests : 150,753
# population : 85,799
#
# country : Congo
# total cases : 24,049
# total deaths : 378
# total recovered : 20,178
# active cases : 3,493
# serious critical : None
# total tests : 347,815
# population : 5,748,989
#
# country : Saint Lucia
# total cases : 22,870
# total deaths : 365
# total recovered : 22,468
# active cases : 37
# serious critical : 1
# total tests : 138,567
# population : 185,055
#
# country : Timor-Leste
# total cases : 22,789
# total deaths : 129
# total recovered : 22,596
# active cases : 64
# serious critical : 9
# total tests : 252,951
# population : 1,361,149
#
# country : Taiwan
# total cases : 21,583
# total deaths : 853
# total recovered : 19,451
# active cases : 1,279
# serious critical : None
# total tests : 12,204,336
# population : 23,890,128
#
# country : Burkina Faso
# total cases : 20,751
# total deaths : 375
# total recovered : 20,309
# active cases : 67
# serious critical : None
# total tests : 248,995
# population : 21,877,554
#
# country : Bhutan
# total cases : 20,722
# total deaths : 7
# total recovered : 15,939
# active cases : 4,776
# serious critical : 4
# total tests : 2,061,231
# population : 786,063
#
# country : Cayman Islands
# total cases : 19,433
# total deaths : 22
# total recovered : 8,553
# active cases : 10,858
# serious critical : 2
# total tests : 222,773
# population : 67,035
#
# country : Nicaragua
# total cases : 18,290
# total deaths : 223
# total recovered : 4,225
# active cases : 13,842
# serious critical : None
# total tests : None
# population : 6,758,636
#
# country : South Sudan
# total cases : 17,073
# total deaths : 138
# total recovered : 13,507
# active cases : 3,428
# serious critical : 1
# total tests : 349,306
# population : 11,416,987
#
# country : Gibraltar
# total cases : 16,053
# total deaths : 101
# total recovered : 15,588
# active cases : 364
# serious critical : 10
# total tests : 524,338
# population : 33,674
#
# country : Equatorial Guinea
# total cases : 15,899
# total deaths : 183
# total recovered : 15,679
# active cases : 37
# serious critical : 5
# total tests : 295,501
# population : 1,481,309
#
# country : Djibouti
# total cases : 15,572
# total deaths : 189
# total recovered : 15,376
# active cases : 7
# serious critical : None
# total tests : 291,328
# population : 1,012,439
#
# country : Liechtenstein
# total cases : 14,926
# total deaths : 81
# total recovered : 14,055
# active cases : 790
# serious critical : 8
# total tests : 80,413
# population : 38,314
#
# country : San Marino
# total cases : 14,726
# total deaths : 112
# total recovered : 14,340
# active cases : 274
# serious critical : 4
# total tests : 140,260
# population : 34,052
#
# country : CAR
# total cases : 14,649
# total deaths : 113
# total recovered : 6,859
# active cases : 7,677
# serious critical : 2
# total tests : 81,294
# population : 4,972,584
#
# country : Grenada
# total cases : 13,921
# total deaths : 217
# total recovered : 13,635
# active cases : 69
# serious critical : 4
# total tests : 140,484
# population : 113,410
#
# country : Bermuda
# total cases : 11,989
# total deaths : 125
# total recovered : 11,607
# active cases : 257
# serious critical : None
# total tests : 820,407
# population : 61,886
#
# country : Gambia
# total cases : 11,973
# total deaths : 365
# total recovered : 11,591
# active cases : 17
# serious critical : None
# total tests : 155,686
# population : 2,532,066
#
# country : Greenland
# total cases : 11,901
# total deaths : 20
# total recovered : 2,761
# active cases : 9,120
# serious critical : 4
# total tests : 164,926
# population : 56,938
#
# country : Yemen
# total cases : 11,797
# total deaths : 2,140
# total recovered : 8,901
# active cases : 756
# serious critical : 23
# total tests : 265,253
# population : 30,942,877
#
# country : Dominica
# total cases : 11,643
# total deaths : 62
# total recovered : 11,330
# active cases : 251
# serious critical : None
# total tests : 175,744
# population : 72,290
#
# country : Monaco
# total cases : 9,964
# total deaths : 53
# total recovered : 9,611
# active cases : 300
# serious critical : 4
# total tests : 54,960
# population : 39,715
#
# country : Saint Martin
# total cases : 9,912
# total deaths : 63
# total recovered : 1,399
# active cases : 8,450
# serious critical : 7
# total tests : 112,382
# population : 39,787
#
# country : Eritrea
# total cases : 9,722
# total deaths : 103
# total recovered : 9,617
# active cases : 2
# serious critical : None
# total tests : 23,693
# population : 3,629,914
#
# country : Sint Maarten
# total cases : 9,631
# total deaths : 85
# total recovered : 9,516
# active cases : 30
# serious critical : 10
# total tests : 62,056
# population : 43,704
#
# country : Solomon Islands
# total cases : 9,412
# total deaths : 125
# total recovered : 2,121
# active cases : 7,166
# serious critical : 4
# total tests : 5,117
# population : 715,520
#
# country : Niger
# total cases : 8,786
# total deaths : 308
# total recovered : 8,465
# active cases : 13
# serious critical : 1
# total tests : 235,282
# population : 25,695,357
#
# country : Comoros
# total cases : 8,074
# total deaths : 160
# total recovered : 7,892
# active cases : 22
# serious critical : None
# total tests : None
# population : 901,099
#
# country : Guinea-Bissau
# total cases : 8,071
# total deaths : 169
# total recovered : 7,077
# active cases : 825
# serious critical : 6
# total tests : 126,481
# population : 2,047,080
#
# country : Caribbean Netherlands
# total cases : 7,739
# total deaths : 31
# total recovered : 7,609
# active cases : 99
# serious critical : None
# total tests : 30,126
# population : 26,638
#
# country : Sierra Leone
# total cases : 7,670
# total deaths : 125
# total recovered : N/A
# active cases : N/A
# serious critical : None
# total tests : 259,958
# population : 8,252,829
#
# country : Antigua and Barbuda
# total cases : 7,470
# total deaths : 135
# total recovered : 7,330
# active cases : 5
# serious critical : 1
# total tests : 18,901
# population : 99,309
#
# country : Liberia
# total cases : 7,397
# total deaths : 294
# total recovered : 5,747
# active cases : 1,356
# serious critical : 2
# total tests : 139,824
# population : 5,259,785
#
# country : Chad
# total cases : 7,267
# total deaths : 190
# total recovered : 4,874
# active cases : 2,203
# serious critical : None
# total tests : 191,341
# population : 17,226,972
#
# country : St. Vincent Grenadines
# total cases : 6,743
# total deaths : 106
# total recovered : 6,636
# active cases : 1
# serious critical : None
# total tests : 98,236
# population : 111,540
#
# country : British Virgin Islands
# total cases : 6,104
# total deaths : 62
# total recovered : N/A
# active cases : N/A
# serious critical : 1
# total tests : 101,161
# population : 30,573
#
# country : Sao Tome and Principe
# total cases : 5,938
# total deaths : 72
# total recovered : 5,862
# active cases : 4
# serious critical : None
# total tests : 29,036
# population : 226,080
#
# country : Turks and Caicos
# total cases : 5,874
# total deaths : 36
# total recovered : 5,808
# active cases : 30
# serious critical : 4
# total tests : 419,792
# population : 39,608
#
# country : Saint Kitts and Nevis
# total cases : 5,541
# total deaths : 42
# total recovered : 5,496
# active cases : 3
# serious critical : 1
# total tests : 65,141
# population : 53,839
#
# country : Palau
# total cases : 3,935
# total deaths : 6
# total recovered : 3,639
# active cases : 290
# serious critical : 1
# total tests : 38,863
# population : 18,241
#
# country : St. Barth
# total cases : 3,780
# total deaths : 6
# total recovered : N/A
# active cases : N/A
# serious critical : None
# total tests : 78,646
# population : 9,928
#
# country : Kiribati
# total cases : 3,041
# total deaths : 13
# total recovered : 2,467
# active cases : 561
# serious critical : 9
# total tests : None
# population : 122,566
#
# country : Anguilla
# total cases : 2,595
# total deaths : 9
# total recovered : 2,572
# active cases : 14
# serious critical : 4
# total tests : 51,382
# population : 15,231
#
# country : Tonga
# total cases : 2,530
# total deaths : 2
# total recovered : 896
# active cases : 1,632
# serious critical : None
# total tests : 84,463
# population : 107,733
#
# country : Saint Pierre Miquelon
# total cases : 1,693
# total deaths : 1
# total recovered : 1,217
# active cases : 475
# serious critical : 1
# total tests : 17,358
# population : 5,746
#
# country : Cook Islands
# total cases : 476
# total deaths :
# total recovered : 132
# active cases : 344
# serious critical : None
# total tests : 3,537
# population : 17,591
#
# country : Vanuatu
# total cases : 473
# total deaths : 1
# total recovered : 59
# active cases : 413
# serious critical : 2
# total tests : 24,976
# population : 319,348
#
# country : Wallis and Futuna
# total cases : 454
# total deaths : 7
# total recovered : 438
# active cases : 9
# serious critical : None
# total tests : 20,508
# population : 10,904
#
# country : Montserrat
# total cases : 174
# total deaths : 2
# total recovered : 163
# active cases : 9
# serious critical : None
# total tests : 8,359
# population : 4,997
#
# country : Falkland Islands
# total cases : 118
# total deaths :
# total recovered : N/A
# active cases : N/A
# serious critical : None
# total tests : 8,632
# population : 3,652
#
# country : Macao
# total cases : 82
# total deaths :
# total recovered : 79
# active cases : 3
# serious critical : None
# total tests : 5,318
# population : 664,392
#
# country : Samoa
# total cases : 49
# total deaths :
# total recovered : 28
# active cases : 21
# serious critical : None
# total tests : None
# population : 200,657
#
# country : Vatican City
# total cases : 29
# total deaths :
# total recovered : 28
# active cases : 1
# serious critical : None
# total tests : None
# population : 804
#
# country : Western Sahara
# total cases : 10
# total deaths : 1
# total recovered : 8
# active cases : 1
# serious critical : None
# total tests : None
# population : 622,306
#
# country : Niue
# total cases : 1
# total deaths :
# total recovered : None
# active cases : 1
# serious critical : None
# total tests : None
# population : 1,645
#
# country : China
# total cases : 123,773
# total deaths : 4,636
# total recovered : 104,287
# active cases : 14,850
# serious critical : 16
# total tests : 160,000,000
# population : 1,439,323,776
# Please type the country of whose information you want to get or type 'skip' to move forwardindia
#
# country : India
# total cases : 43,001,477
# total deaths : 516,162
# total recovered : 42,454,546
# active cases : 30,769
# serious critical : 8,944
# total tests : 781,224,304
# population : 1,403,087,655
